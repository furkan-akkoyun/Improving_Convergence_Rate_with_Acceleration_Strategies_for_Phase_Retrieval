# %% [markdown]
# # Structured Random Forward Model Comparison
#
# Structured random forward model comparison using the report method configuration.

# %%
from pathlib import Path
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    if (candidate / "report_experiments_split").exists():
        sys.path.insert(0, str(candidate))
        break

from report_experiments_split import config, problem, metrics, runners, plotting, common, experiment_configs
import importlib
importlib.reload(config)
importlib.reload(problem)
importlib.reload(metrics)
importlib.reload(runners)
importlib.reload(plotting)
importlib.reload(common)
importlib.reload(experiment_configs)
from report_experiments_split.experiments import structured_random_forward_model

importlib.reload(structured_random_forward_model)

outputs = structured_random_forward_model.run()
summary = outputs.get('summary')
summary
# Out:
# device: cuda
# image shape: (1, 1, 32, 32) phase img size: (1, 32, 32) signal shape: (1, 1, 32, 32) n: 1024
# run: method=GD, model=structured, loss=intensity, init=spectral, alpha=4.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 1, 64, 64)
# run: method=Accelerated GD, model=structured, loss=intensity, init=spectral, alpha=4.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 1, 64, 64)
# run: method=Adam, model=structured, loss=intensity, init=spectral, alpha=4.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 1, 64, 64)
# run: method=NCG, model=structured, loss=intensity, init=spectral, alpha=4.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 1, 64, 64)
# run: method=L-BFGS, model=structured, loss=intensity, init=spectral, alpha=4.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 1, 64, 64)
# ...
