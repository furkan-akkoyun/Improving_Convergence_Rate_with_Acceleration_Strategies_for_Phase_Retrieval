# %% [markdown]
# # Oversampling Ratio Experiments
#
# Runs only the non-baseline oversampling ratios alpha=2 and alpha=10, each with its own convergence plots.

# %%
from pathlib import Path
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    if (candidate / "report_experiments_split").exists():
        sys.path.insert(0, str(candidate))
        break

from report_experiments_split import config, problem, metrics, runners, plotting, common, experiment_configs
import importlib
importlib.reload(config)
importlib.reload(problem)
importlib.reload(metrics)
importlib.reload(runners)
importlib.reload(plotting)
importlib.reload(common)
importlib.reload(experiment_configs)
from report_experiments_split.experiments import oversampling_ratio

importlib.reload(oversampling_ratio)

outputs = oversampling_ratio.run()
summary = outputs.get('summary')
summary
# Out:
# device: cuda
# image shape: (1, 1, 32, 32) phase img size: (1, 32, 32) signal shape: (1, 1, 32, 32) n: 1024
# run: method=GD, model=deepinv_random, loss=intensity, init=spectral, alpha=2.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 2048)
# run: method=Accelerated GD, model=deepinv_random, loss=intensity, init=spectral, alpha=2.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 2048)
# run: method=Adam, model=deepinv_random, loss=intensity, init=spectral, alpha=2.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 2048)
# run: method=NCG, model=deepinv_random, loss=intensity, init=spectral, alpha=2.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 2048)
# run: method=L-BFGS, model=deepinv_random, loss=intensity, init=spectral, alpha=2.0, noise=0.0
#     shapes: x_true=(1, 1, 32, 32), x_init=(1, 1, 32, 32), y=(1, 2048)
# ...
